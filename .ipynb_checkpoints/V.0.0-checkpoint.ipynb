# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score,f1_score, roc_auc_score

np.random.seed(123)
# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

# %%
data = pd.read_csv("anylogic_dataset_800.csv")
data.head()
# Out:
#    vehicle_id  vehicle_localmips  total_tasks  total_task_mips  \
# 0         307        2733.266310         1068      790819.8329
# 1         310        1400.104299          314      235023.5362
# 2         313        1193.868292          380      287256.1731
# 3         316        1797.806593          428      320964.2627
# 4         319        1333.797887          322      243113.6927
#
#    tasks_completed_local  local_failed  tasks_from_others  other_task_mips  \
# 0                    265             0                803     594288.74260
# 1                    269             0                 45      34683.77499
# 2                    313             0                 67      52298.72333
# 3                    131             0                297     222200.04570
# 4                    139             0                183     137793.91030
#
#    others_completed  others_failed  total_execution_time  \
# 0               787             16            289.331424
# 1                26             19            167.861449
# 2                25             42            240.609601
# 3               297              0            178.531030
# 4               183              0            182.271763
#
#    total_computation_time  simulation_time  trust_factor    z_score  \
# 0              284.788121             6000  20834.143720   0.201158
# 1              157.939327             6000    492.803679  13.768739
# 2              212.596029             6000  -1222.103462   7.935582
# 3              178.531030             6000  12359.507780   0.461767
# 4              182.271763             6000  10330.943820   0.953057
#
#    other_total_comp_time
# 0             212.884740
# 1              14.850158
# 2              15.792537
# 3             123.595078
# 4             103.309438

# %%
#shuffle the dataset
data = data.sample(frac=1)
data.head()
# Out:
#      vehicle_id  vehicle_localmips  total_tasks  total_task_mips  \
# 145         742        1941.363448          601      454112.1978
# 571        2327        2761.908509          800      601453.1785
# 229         994        3362.202157          916      683848.9494
# 202         913        1051.868417          252      189365.2455
# 185         862        2072.033006          506      378822.3153
#
#      tasks_completed_local  local_failed  tasks_from_others  other_task_mips  \
# 145                    276             0                325      244987.7572
# 571                    247             0                553      417387.6325
# 229                    145             0                771      574738.0715
# 202                     42             0                210      157055.3680
# 185                     93             0                413      311976.9235
#
#      others_completed  others_failed  total_execution_time  \
# 145               271             54            233.914056
# 571               542             11            217.767235
# 229               770              1            203.393168
# 202               150             60            180.027504
# 185               380             33            182.826390
#
#      total_computation_time  simulation_time  trust_factor   z_score  \
# 145              213.547394             6000   8546.033628  1.889005
# 571              214.683358             6000  14495.514910  0.249898
# 229              203.127732             6000  17041.009010  0.170618
# 202              136.764726             6000   6278.529612  4.744965
# 185              170.687379             6000  12628.759220  1.087380
#
#      other_total_comp_time
# 145             105.826998
# 571             148.039026
# 229             170.675526
# 202             106.048073
# 185             138.426603

# %%
data.reset_index(inplace=True,drop=True)
data.head()
# Out:
#    vehicle_id  vehicle_localmips  total_tasks  total_task_mips  \
# 0         742        1941.363448          601      454112.1978
# 1        2327        2761.908509          800      601453.1785
# 2         994        3362.202157          916      683848.9494
# 3         913        1051.868417          252      189365.2455
# 4         862        2072.033006          506      378822.3153
#
#    tasks_completed_local  local_failed  tasks_from_others  other_task_mips  \
# 0                    276             0                325      244987.7572
# 1                    247             0                553      417387.6325
# 2                    145             0                771      574738.0715
# 3                     42             0                210      157055.3680
# 4                     93             0                413      311976.9235
#
#    others_completed  others_failed  total_execution_time  \
# 0               271             54            233.914056
# 1               542             11            217.767235
# 2               770              1            203.393168
# 3               150             60            180.027504
# 4               380             33            182.826390
#
#    total_computation_time  simulation_time  trust_factor   z_score  \
# 0              213.547394             6000   8546.033628  1.889005
# 1              214.683358             6000  14495.514910  0.249898
# 2              203.127732             6000  17041.009010  0.170618
# 3              136.764726             6000   6278.529612  4.744965
# 4              170.687379             6000  12628.759220  1.087380
#
#    other_total_comp_time
# 0             105.826998
# 1             148.039026
# 2             170.675526
# 3             106.048073
# 4             138.426603

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 16 columns):
# vehicle_id                800 non-null int64
# vehicle_localmips         800 non-null float64
# total_tasks               800 non-null int64
# total_task_mips           800 non-null float64
# tasks_completed_local     800 non-null int64
# local_failed              800 non-null int64
# tasks_from_others         800 non-null int64
# other_task_mips           800 non-null float64
# others_completed          800 non-null int64
# others_failed             800 non-null int64
# total_execution_time      800 non-null float64
# total_computation_time    800 non-null float64
# simulation_time           800 non-null int64
# trust_factor              800 non-null float64
# z_score                   800 non-null float64
# other_total_comp_time     800 non-null float64
# dtypes: float64(8), int64(8)
# memory usage: 100.1 KB

# %%
df = pd.DataFrame(data['trust_factor'])
x = df[['trust_factor']].values.astype(float)
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df_normalized = df_normalized.round(1)
data["normalized_trust_values"] = df_normalized
data.head()
# Out:
#    vehicle_id  vehicle_localmips  total_tasks  total_task_mips  \
# 0         742        1941.363448          601      454112.1978
# 1        2327        2761.908509          800      601453.1785
# 2         994        3362.202157          916      683848.9494
# 3         913        1051.868417          252      189365.2455
# 4         862        2072.033006          506      378822.3153
#
#    tasks_completed_local  local_failed  tasks_from_others  other_task_mips  \
# 0                    276             0                325      244987.7572
# 1                    247             0                553      417387.6325
# 2                    145             0                771      574738.0715
# 3                     42             0                210      157055.3680
# 4                     93             0                413      311976.9235
#
#    others_completed  others_failed  total_execution_time  \
# 0               271             54            233.914056
# 1               542             11            217.767235
# 2               770              1            203.393168
# 3               150             60            180.027504
# 4               380             33            182.826390
#
#    total_computation_time  simulation_time  trust_factor   z_score  \
# 0              213.547394             6000   8546.033628  1.889005
# 1              214.683358             6000  14495.514910  0.249898
# 2              203.127732             6000  17041.009010  0.170618
# 3              136.764726             6000   6278.529612  4.744965
# 4              170.687379             6000  12628.759220  1.087380
#
#    other_total_comp_time  normalized_trust_values
# 0             105.826998                      0.5
# 1             148.039026                      0.7
# 2             170.675526                      0.8
# 3             106.048073                      0.4
# 4             138.426603                      0.6

# %%
criteria = [data['normalized_trust_values'].between(0.0, 0.3), data['normalized_trust_values'].between(0.4, 0.6), data['normalized_trust_values'].between(0.7, 1.0)]
# values = ['Malicious', 'Partially Trusted', 'Trusted']
values = [0, 1, 2]

data['trust_labels'] = np.select(criteria, values, 0)
data.head()
# Out:
#    vehicle_id  vehicle_localmips  total_tasks  total_task_mips  \
# 0         742        1941.363448          601      454112.1978
# 1        2327        2761.908509          800      601453.1785
# 2         994        3362.202157          916      683848.9494
# 3         913        1051.868417          252      189365.2455
# 4         862        2072.033006          506      378822.3153
#
#    tasks_completed_local  local_failed  tasks_from_others  other_task_mips  \
# 0                    276             0                325      244987.7572
# 1                    247             0                553      417387.6325
# 2                    145             0                771      574738.0715
# 3                     42             0                210      157055.3680
# 4                     93             0                413      311976.9235
#
#    others_completed  others_failed  total_execution_time  \
# 0               271             54            233.914056
# 1               542             11            217.767235
# 2               770              1            203.393168
# 3               150             60            180.027504
# 4               380             33            182.826390
#
#    total_computation_time  simulation_time  trust_factor   z_score  \
# 0              213.547394             6000   8546.033628  1.889005
# 1              214.683358             6000  14495.514910  0.249898
# 2              203.127732             6000  17041.009010  0.170618
# 3              136.764726             6000   6278.529612  4.744965
# 4              170.687379             6000  12628.759220  1.087380
#
#    other_total_comp_time  normalized_trust_values  trust_labels
# 0             105.826998                      0.5             1
# 1             148.039026                      0.7             2
# 2             170.675526                      0.8             2
# 3             106.048073                      0.4             1
# 4             138.426603                      0.6             1

# %%
data = data.drop(['vehicle_id', 'local_failed', 'tasks_completed_local',  'simulation_time', 'trust_factor', 'z_score'], axis=1)
data = data.drop(['normalized_trust_values', 'total_task_mips', 'total_execution_time', 'total_tasks', 'total_computation_time'], axis=1)

# %%
pd.set_option('float_format', '{:f}'.format)
data.describe().T
# Out:
#                            count          mean           std          min  \
# vehicle_localmips     800.000000   2234.627797    730.957858  1002.883792
# tasks_from_others     800.000000    425.898750    172.580085    45.000000
# other_task_mips       800.000000 319240.798556 129178.395349 34683.774990
# others_completed      800.000000    392.661250    188.391316     5.000000
# others_failed         800.000000     33.237500     40.328732     0.000000
# other_total_comp_time 800.000000    128.568390     40.411348     3.927303
# trust_labels          800.000000      1.201250      0.603078     0.000000
#
#                                 25%           50%           75%           max
# vehicle_localmips       1578.471382   2270.615249   2884.001215   3490.773797
# tasks_from_others        290.750000    410.000000    525.250000    982.000000
# other_task_mips       218512.846950 307237.309850 394702.536600 732807.080000
# others_completed         240.750000    384.500000    506.000000    982.000000
# others_failed              1.000000     18.000000     51.000000    216.000000
# other_total_comp_time    103.627617    125.535674    152.272131    246.785365
# trust_labels               1.000000      1.000000      2.000000      2.000000

# %%
data['trust_labels'].value_counts().plot(kind = 'bar')

# %%
data['trust_labels'].value_counts()
# Out:
# 1    477
# 2    242
# 0     81
# Name: trust_labels, dtype: int64

# %%
#check missing
data.isnull().sum().sum()
# Out:
# 0

# %%
#data['avgmips_per_task'] = data['other_task_mips'] / data['tasks_from_others']
#data['avgcomp_per_task'] = data['other_total_comp_time'] / data['others_completed']
#data.head()

# %%
corr = data.corr()
cmap = sns.diverging_palette(220, 10, as_cmap=True)
f, ax = plt.subplots(figsize=(21, 19))
sns.heatmap(corr, cmap=cmap, center=0,annot = True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
corr
# Out:
#                        vehicle_localmips  tasks_from_others  other_task_mips  \
# vehicle_localmips               1.000000           0.656435         0.656654
# tasks_from_others               0.656435           1.000000         0.999735
# other_task_mips                 0.656654           0.999735         1.000000
# others_completed                0.750016           0.978833         0.978697
# others_failed                  -0.694517          -0.293178        -0.293678
# other_total_comp_time           0.238603           0.842393         0.842594
# trust_labels                    0.456628           0.754519         0.755207
#
#                        others_completed  others_failed  other_total_comp_time  \
# vehicle_localmips              0.750016      -0.694517               0.238603
# tasks_from_others              0.978833      -0.293178               0.842393
# other_task_mips                0.978697      -0.293678               0.842594
# others_completed               1.000000      -0.482641               0.793823
# others_failed                 -0.482641       1.000000              -0.103378
# other_total_comp_time          0.793823      -0.103378               1.000000
# trust_labels                   0.786088      -0.443284               0.790730
#
#                        trust_labels
# vehicle_localmips          0.456628
# tasks_from_others          0.754519
# other_task_mips            0.755207
# others_completed           0.786088
# others_failed             -0.443284
# other_total_comp_time      0.790730
# trust_labels               1.000000

# %%
sns.pairplot(data);

# %%
sns.pairplot(data);

# %%
len(data.columns)
# Out:
# 7

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# find best scored k features
select_feature = SelectKBest(chi2, k='all').fit(data.drop('trust_labels',axis = 1 ), data['trust_labels'])

print('Score list:', select_feature.scores_)
print('Feature list:', data.columns)
select_feature
# Out:
# Score list: [4.62891337e+04 3.29562217e+04 2.46739945e+07 4.48995454e+04
#  1.18295017e+04 6.48014724e+03]
# Feature list: Index(['vehicle_localmips', 'tasks_from_others', 'other_task_mips',
#        'others_completed', 'others_failed', 'other_total_comp_time',
#        'trust_labels'],
#       dtype='object')
# SelectKBest(k='all', score_func=<function chi2 at 0x000002DE254A1EA0>)

# %%
select_feature.transform(data.drop('trust_labels',axis = 1))
# Out:
# array([[1.94136345e+03, 3.25000000e+02, 2.44987757e+05, 2.71000000e+02,
#         5.40000000e+01, 1.05826998e+02],
#        [2.76190851e+03, 5.53000000e+02, 4.17387633e+05, 5.42000000e+02,
#         1.10000000e+01, 1.48039026e+02],
#        [3.36220216e+03, 7.71000000e+02, 5.74738071e+05, 7.70000000e+02,
#         1.00000000e+00, 1.70675526e+02],
#        ...,
#        [1.47191347e+03, 2.19000000e+02, 1.64598597e+05, 1.30000000e+02,
#         8.90000000e+01, 6.66114419e+01],
#        [1.82261736e+03, 5.76000000e+02, 4.34475007e+05, 5.07000000e+02,
#         6.90000000e+01, 2.09886884e+02],
#        [1.01276685e+03, 2.11000000e+02, 1.60102328e+05, 1.01000000e+02,
#         1.10000000e+02, 7.49624246e+01]])

# %%
selected_columns = np.array(data.drop('trust_labels',axis = 1).columns)[select_feature.get_support()]
selected_columns
# Out:
# array(['vehicle_localmips', 'tasks_from_others', 'other_task_mips',
#        'others_completed', 'others_failed', 'other_total_comp_time'],
#       dtype=object)

# %%
ABT = pd.DataFrame(select_feature.transform(data.drop('trust_labels',axis = 1)),columns=selected_columns)
y = data.trust_labels

# %%
compare = pd.DataFrame(index=['RandomForest', 'SVM', 'LogisticRegression', 'kNN', 'Naive Bayes'], 
                      columns=['Accuracy', 'f1 score', 'Precision', 'Recall'])
compare
# Out:
#                    Accuracy f1 score Precision Recall
# RandomForest            NaN      NaN       NaN    NaN
# SVM                     NaN      NaN       NaN    NaN
# LogisticRegression      NaN      NaN       NaN    NaN
# kNN                     NaN      NaN       NaN    NaN
# Naive Bayes             NaN      NaN       NaN    NaN

# %%
X_train, X_test, y_train, y_test = train_test_split(ABT, y, test_size=0.2, random_state=0)
X_train, X_v, y_train, y_v = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
rf = RandomForestClassifier(criterion='gini', n_estimators=1000, max_depth=3, random_state=0, n_jobs=-1)      
rf = rf.fit(X_train,y_train)

y_pred = rf.predict(X_v)
print(f'Accuracy on validation set is {accuracy_score(y_v,y_pred)}')
print(f'f1 score on validation set is {f1_score(y_true=y_v, y_pred=y_pred, average=None)}')
print(f'Precision on validation set is {precision_score(y_true=y_v, y_pred=y_pred, average=None)}')
print(f'Recall on validation set is {recall_score(y_true=y_v, y_pred=y_pred, average=None)}')
confmat = confusion_matrix(y_v,y_pred)
sns.heatmap(confmat,annot=True,fmt="d")
# Out:
# Accuracy on validation set is 0.8984375
# f1 score on validation set is [0.81481481 0.91925466 0.88235294]
# Precision on validation set is [0.84615385 0.88095238 0.96774194]
# Recall on validation set is [0.78571429 0.96103896 0.81081081]

# %%
y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test,y_pred)
f1 = f1_score(y_true=y_test, y_pred=y_pred, average=None)
precision = precision_score(y_true=y_test, y_pred=y_pred, average=None)
recall = recall_score(y_true=y_test, y_pred=y_pred, average=None)


compare.at['RandomForest', :] = (accuracy, f1, precision, recall)

print(f'Accuracy on test set is {accuracy}')
print(f'f1 score on test set is {f1}')
print(f'Precision on test set is {precision}')
print(f'Recall on test set is {recall}')


confmat = confusion_matrix(y_test,y_pred)
sns.heatmap(confmat,annot=True,fmt="d")
# Out:
# Accuracy on test set is 0.925
# f1 score on test set is [0.83870968 0.9375     0.92783505]
# Precision on test set is [1.         0.88235294 1.        ]
# Recall on test set is [0.72222222 1.         0.86538462]

# %%
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
NormalizedABT = min_max_scaler.fit_transform(ABT)
NormalizedABT=pd.DataFrame(NormalizedABT, columns=selected_columns)
X_train, X_test, y_train, y_test = train_test_split(NormalizedABT, y, test_size=0.2, random_state=0)
X_train, X_v, y_train, y_v = train_test_split(X_train, y_train, test_size=0.2, random_state=0)
NormalizedABT.describe().T
# Out:
#                            count     mean      std      min      25%      50%  \
# vehicle_localmips     800.000000 0.495096 0.293806 0.000000 0.231356 0.509561
# tasks_from_others     800.000000 0.406509 0.184184 0.000000 0.262273 0.389541
# other_task_mips       800.000000 0.407603 0.185037 0.000000 0.263319 0.390409
# others_completed      800.000000 0.396787 0.192826 0.000000 0.241300 0.388434
# others_failed         800.000000 0.153877 0.186707 0.000000 0.004630 0.083333
# other_total_comp_time 800.000000 0.513226 0.166399 0.000000 0.410529 0.500738
#
#                            75%      max
# vehicle_localmips     0.756110 1.000000
# tasks_from_others     0.512540 1.000000
# other_task_mips       0.515695 1.000000
# others_completed      0.512794 1.000000
# others_failed         0.236111 1.000000
# other_total_comp_time 0.610829 1.000000

# %%
from sklearn import svm

clf = svm.SVC().fit(X_train, y_train)
y_pred = clf.predict(X_v)

print(f'Accuracy on validation set is {accuracy_score(y_v,y_pred)}')
print(f'f1 score on validation set is {f1_score(y_true=y_v, y_pred=y_pred, average=None)}')
print(f'Precision on validation set is {precision_score(y_true=y_v, y_pred=y_pred, average=None)}')
print(f'Recall on validation set is {recall_score(y_true=y_v, y_pred=y_pred, average=None)}')

confmat = confusion_matrix(y_v,y_pred)
sns.heatmap(confmat,annot=True,fmt="d")
# Out:
# Accuracy on validation set is 0.8515625
# f1 score on validation set is [0.6        0.88888889 0.83076923]
# Precision on validation set is [1.         0.80851064 0.96428571]
# Recall on validation set is [0.42857143 0.98701299 0.72972973]

# %%
y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test,y_pred)
f1 = f1_score(y_true=y_test, y_pred=y_pred, average=None)
precision = precision_score(y_true=y_test, y_pred=y_pred, average=None)
recall = recall_score(y_true=y_test, y_pred=y_pred, average=None)

compare.at['SVM', :] = (accuracy, f1, precision, recall)

print(f'Accuracy on test set is {accuracy}')
print(f'f1 score on test set is {f1}')
print(f'Precision on test set is {precision}')
print(f'Recall on test set is {recall}')

confmat = confusion_matrix(y_test,y_pred)
sns.heatmap(confmat,annot=True,fmt="d")
# Out:
# Accuracy on test set is 0.85
# f1 score on test set is [0.36363636 0.88235294 0.89361702]
# Precision on test set is [1.         0.78947368 1.        ]
# Recall on test set is [0.22222222 1.         0.80769231]

# %%
X_train, X_test, y_train, y_test = train_test_split(ABT, y, test_size=0.2, random_state=0)
X_train, X_v, y_train, y_v = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(random_state=0).fit(X_train, y_train)
y_pred = clf.predict(X_v)

print(f'Accuracy on validation set is {accuracy_score(y_v,y_pred)}')
print(f'f1 score on validation set is {f1_score(y_true=y_v, y_pred=y_pred, average=None)}')
print(f'Precision on validation set is {precision_score(y_true=y_v, y_pred=y_pred, average=None)}')
print(f'Recall on validation set is {recall_score(y_true=y_v, y_pred=y_pred, average=None)}')

confmat = confusion_matrix(y_v,y_pred)
sns.heatmap(confmat,annot=True,fmt="d")
# Out:
# Accuracy on validation set is 0.8984375
# f1 score on validation set is [0.63636364 0.92121212 0.92753623]
# Precision on validation set is [0.875      0.86363636 1.        ]
# Recall on validation set is [0.5        0.98701299 0.86486486]

# %%
y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test,y_pred)
f1 = f1_score(y_true=y_test, y_pred=y_pred, average=None)
precision = precision_score(y_true=y_test, y_pred=y_pred, average=None)
recall = recall_score(y_true=y_test, y_pred=y_pred, average=None)

compare.at['LogisticRegression', :] = (accuracy, f1, precision, recall)

print(f'Accuracy on test set is {accuracy}')
print(f'f1 score on test set is {f1}')
print(f'Precision on test set is {precision}')
print(f'Recall on test set is {recall}')


confmat = confusion_matrix(y_test,y_pred)
sns.heatmap(confmat,annot=True,fmt="d")
# Out:
# Accuracy on test set is 0.9375
# f1 score on test set is [0.75862069 0.94736842 0.97029703]
# Precision on test set is [1.  0.9 1. ]
# Recall on test set is [0.61111111 1.         0.94230769]

# %%
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
NormalizedABT = min_max_scaler.fit_transform(ABT)
NormalizedABT=pd.DataFrame(NormalizedABT, columns=selected_columns)
X_train, X_test, y_train, y_test = train_test_split(NormalizedABT, y, test_size=0.2, random_state=0)
X_train, X_v, y_train, y_v = train_test_split(X_train, y_train, test_size=0.2, random_state=0)
NormalizedABT.describe().T
# Out:
#                            count     mean      std      min      25%      50%  \
# vehicle_localmips     800.000000 0.495096 0.293806 0.000000 0.231356 0.509561
# tasks_from_others     800.000000 0.406509 0.184184 0.000000 0.262273 0.389541
# other_task_mips       800.000000 0.407603 0.185037 0.000000 0.263319 0.390409
# others_completed      800.000000 0.396787 0.192826 0.000000 0.241300 0.388434
# others_failed         800.000000 0.153877 0.186707 0.000000 0.004630 0.083333
# other_total_comp_time 800.000000 0.513226 0.166399 0.000000 0.410529 0.500738
#
#                            75%      max
# vehicle_localmips     0.756110 1.000000
# tasks_from_others     0.512540 1.000000
# other_task_mips       0.515695 1.000000
# others_completed      0.512794 1.000000
# others_failed         0.236111 1.000000
# other_total_comp_time 0.610829 1.000000

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=19).fit(X_train, y_train)

y_pred = clf.predict(X_v)

print(f'Accuracy on validation set is {accuracy_score(y_v,y_pred)}')
print(f'f1 score on validation set is {f1_score(y_true=y_v, y_pred=y_pred, average=None)}')
print(f'Precision on validation set is {precision_score(y_true=y_v, y_pred=y_pred, average=None)}')
print(f'Recall on validation set is {recall_score(y_true=y_v, y_pred=y_pred, average=None)}')

confmat = confusion_matrix(y_v,y_pred)
sns.heatmap(confmat,annot=True,fmt="d")
# Out:
# Accuracy on validation set is 0.9375
# f1 score on validation set is [0.96296296 0.95       0.89855072]
# Precision on validation set is [1.         0.91566265 0.96875   ]
# Recall on validation set is [0.92857143 0.98701299 0.83783784]

# %%
y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test,y_pred)
f1 = f1_score(y_true=y_test, y_pred=y_pred, average=None)
precision = precision_score(y_true=y_test, y_pred=y_pred, average=None)
recall = recall_score(y_true=y_test, y_pred=y_pred, average=None)

compare.at['kNN', :] = (accuracy, f1, precision, recall)

print(f'Accuracy on test set is {accuracy}')
print(f'f1 score on test set is {f1}')
print(f'Precision on test set is {precision}')
print(f'Recall on test set is {recall}')

confmat = confusion_matrix(y_test,y_pred)
sns.heatmap(confmat,annot=True,fmt="d")
# Out:
# Accuracy on test set is 0.94375
# f1 score on test set is [0.94117647 0.95187166 0.92929293]
# Precision on test set is [1.         0.91752577 0.9787234 ]
# Recall on test set is [0.88888889 0.98888889 0.88461538]

# %%
X_train, X_test, y_train, y_test = train_test_split(ABT, y, test_size=0.2, random_state=0)
X_train, X_v, y_train, y_v = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB

clf = GaussianNB().fit(X_train, y_train)

y_pred = clf.predict(X_v)

print(f'Accuracy on validation set is {accuracy_score(y_v,y_pred)}')
print(f'f1 score on validation set is {f1_score(y_true=y_v, y_pred=y_pred, average=None)}')
print(f'Precision on validation set is {precision_score(y_true=y_v, y_pred=y_pred, average=None)}')
print(f'Recall on validation set is {recall_score(y_true=y_v, y_pred=y_pred, average=None)}')

confmat = confusion_matrix(y_v,y_pred)
sns.heatmap(confmat,annot=True,fmt="d")
# Out:
# Accuracy on validation set is 0.8046875
# f1 score on validation set is [0.66666667 0.82269504 0.84931507]
# Precision on validation set is [0.5        0.90625    0.86111111]
# Recall on validation set is [1.         0.75324675 0.83783784]

# %%
y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test,y_pred)
f1 = f1_score(y_true=y_test, y_pred=y_pred, average=None)
precision = precision_score(y_true=y_test, y_pred=y_pred, average=None)
recall = recall_score(y_true=y_test, y_pred=y_pred, average=None)

compare.at['Naive Bayes', :] = (accuracy, f1, precision, recall)

print(f'Accuracy on test set is {accuracy}')
print(f'f1 score on test set is {f1}')
print(f'Precision on test set is {precision}')
print(f'Recall on test set is {recall}')

confmat = confusion_matrix(y_test,y_pred)
sns.heatmap(confmat,annot=True,fmt="d")
# Out:
# Accuracy on test set is 0.83125
# f1 score on test set is [0.70588235 0.84023669 0.88      ]
# Precision on test set is [0.54545455 0.89873418 0.91666667]
# Recall on test set is [1.         0.78888889 0.84615385]

# %%
compare
# Out:
#                    Accuracy  \
# RandomForest       0.925000
# SVM                0.850000
# LogisticRegression 0.937500
# kNN                0.943750
# Naive Bayes        0.831250
#
#                                                              f1 score  \
# RandomForest         [0.8387096774193548, 0.9375, 0.9278350515463918]
# SVM                 [0.3636363636363636, 0.8823529411764706, 0.893...
# LogisticRegression  [0.7586206896551725, 0.9473684210526316, 0.970...
# kNN                 [0.9411764705882353, 0.9518716577540107, 0.929...
# Naive Bayes         [0.7058823529411764, 0.8402366863905325, 0.879...
#
#                                                             Precision  \
# RandomForest                           [1.0, 0.8823529411764706, 1.0]
# SVM                                    [1.0, 0.7894736842105263, 1.0]
# LogisticRegression                                    [1.0, 0.9, 1.0]
# kNN                     [1.0, 0.9175257731958762, 0.9787234042553191]
# Naive Bayes         [0.5454545454545454, 0.8987341772151899, 0.916...
#
#                                                                Recall
# RandomForest            [0.7222222222222222, 1.0, 0.8653846153846154]
# SVM                     [0.2222222222222222, 1.0, 0.8076923076923077]
# LogisticRegression      [0.6111111111111112, 1.0, 0.9423076923076923]
# kNN                 [0.8888888888888888, 0.9888888888888889, 0.884...
# Naive Bayes             [1.0, 0.7888888888888889, 0.8461538461538461]
